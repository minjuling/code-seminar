# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp')
# Out:
# Text(0.5, 1.0, 'A simple chirp')

# %%
accuracy1 = [36.60166561603546, 51.321667432785034, 61.87499761581421, 67.80833601951599, 71.13166451454163, 74.38333630561829, 77.78833508491516, 79.90999817848206, 81.66999816894531, 83.21166634559631]
loss1 = [0.003785297041758895, 0.0036907366011291742, 0.0035152030177414417, 0.003160786349326372, 0.002705325372517109, 0.0020772889256477356, 0.0015643594088032842, 0.0014784745872020721, 0.00128951296210289, 0.0011073306668549776]
accuracy2 = [82.74666666984558, 87.99166679382324, 89.53499794006348, 90.01166820526123, 90.84166884422302, 91.88166856765747, 91.97499752044678, 92.57833361625671, 92.97500252723694, 93.31333041191101]
loss2 = [0.001089665456674993, 0.0006705798441544175, 0.0004619342216756195, 0.000546972150914371, 0.000592411553952843, 0.00046678329817950726, 0.00041731944656930864, 0.0006142783677205443, 0.0005794110475108027, 0.0003092066617682576]
accuracy3 = [92.76999831199646, 95.91166377067566, 97.2000002861023, 97.00000286102295, 97.50666618347168, 98.31833243370056, 98.19666743278503, 98.63666892051697, 98.29166531562805, 98.87166619300842]
loss3 = [0.0004013091966044158, 0.0002079979021800682, 0.0001471198775107041, 5.712196070817299e-05, 0.0002218797744717449, 6.51072186883539e-05, 0.00010084307723445818, 1.6917991160880774e-05, 0.00013333918468561023, 5.890687316423282e-05]

epochs = 10

# %%
plt.title('NN')

plt.plot(range(1,epochs+1), accuracy1)

plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()

plt.plot(range(1,epochs+1), loss1)

plt.xlabel('epochs')
plt.ylabel('loss')

plt.show()

# %%
plt.title('NN+lr(r:lr = 0.001, g: lr = 0.01, b: lr = 0.1)')

plt.plot(range(1,epochs+1), accuracy1,'r')
plt.plot(range(1,epochs+1), accuracy2,'g')
plt.plot(range(1,epochs+1), accuracy3,'b')

plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()

plt.plot(range(1,epochs+1), loss1,'r')
plt.plot(range(1,epochs+1), loss2,'g')
plt.plot(range(1,epochs+1), loss3,'b')

plt.xlabel('epochs')
plt.ylabel('loss')

plt.show()
